# %% [markdown]
# # Data Analysis with Pandas (1st Part)

# %% [markdown]
# **Outline:**
#
# * [Intro to Pandas](#Intro-to-Pandas)
# * [Pandas Data Structures](#Pandas-Data-Structures)
#   * [Python List](#Python-List)
#   * [Series](#Series)
#   * [DataFrame](#DataFrame)
# * [Pandas Data Types](#Pandas-Data-Types)
# * [Knowing Basic Stats](#Knowing-Basic-Stats)
# * [Dealing with Files](#Dealing-with-Files)
#   * [Reading Data from File](#Reading-Data-from-File)
#   * [Writing Data to File](#Writing-Data-to-File)
# * [Dealing with Columns](#Dealing-with-Columns)
#   * [Renaming Columns](#Renaming-Columns)
#   * [Adding New Columns](#Adding-New-Columns)
#   * [Removing Existing Columns](#Removing-Existing-Columns)

# %% [markdown]
# ## Intro to Pandas

# %%
from IPython.core.display import HTML
HTML("<iframe src=http://pandas.pydata.org width=800 height=350></iframe>")
# Out:
# <iframe src=http://pandas.pydata.org width=800 height=350></iframe>

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Data Structures

# %% [markdown]
# ### Python List

# %%
data = [113, 1463, 95, 33]
data[2]
# Out:
# 95

# %% [markdown]
# ### Series

# %%
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
series_data = pd.Series([113, 1463, 95, 33])
series_data
# Out:
# 0     113
# 1    1463
# 2      95
# 3      33
# dtype: int64

# %%
type(series_data)
# Out:
# pandas.core.series.Series

# %%
series_data[2]
# Out:
# 95

# %%
series_data = pd.Series({'a': 113, 'b': 1463, 'c': 95, 'd': 33})
series_data
# Out:
# a     113
# b    1463
# c      95
# d      33
# dtype: int64

# %%
series_data[1]
# Out:
# 1463

# %%
series_data['b']
# Out:
# 1463

# %%
series_data = pd.Series({'a': 113, 'b': 1463, 'c': 95, 'd': 33}, index=['b', 'c', 'd', 'e', 'f'])
series_data
# Out:
# b    1463.0
# c      95.0
# d      33.0
# e       NaN
# f       NaN
# dtype: float64

# %%
series_data.isnull()
# Out:
# b    False
# c    False
# d    False
# e     True
# f     True
# dtype: bool

# %%
series_data.isnull().sum()
# Out:
# 2

# %%
series_data.index
# Out:
# Index(['b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
series_data.values
# Out:
# array([ 1463.,    95.,    33.,    nan,    nan])

# %%
[1, 2, 3] + [3, 4, 6]
# Out:
# [1, 2, 3, 3, 4, 6]

# %%
series_data + series_data
# Out:
# b    2926.0
# c     190.0
# d      66.0
# e       NaN
# f       NaN
# dtype: float64

# %%
series_data.append(pd.Series([113, 1463, 95, 33]))
# Out:
# b    1463.0
# c      95.0
# d      33.0
# e       NaN
# f       NaN
# 0     113.0
# 1    1463.0
# 2      95.0
# 3      33.0
# dtype: float64

# %%
series_data = series_data.append(pd.Series({'b': 99}))

# %%
series_data.index
# Out:
# Index(['b', 'c', 'd', 'e', 'f', 'b'], dtype='object')

# %%
series_data
# Out:
# b    1463.0
# c      95.0
# d      33.0
# e       NaN
# f       NaN
# b      99.0
# dtype: float64

# %%
series_data[5]
# Out:
# 99.0

# %%
series_data['b']
# Out:
# b    1463.0
# b      99.0
# dtype: float64

# %% [markdown]
# ### DataFrame

# %%
personal_data_dict = {
    'age': [39, 50, 38],
    'education': ['Bachelors', 'Bachelors', 'HS-grad'],
    'occupation': ['Adm-clerical', 'Tech-support', 'Sales'],
    'sex': ['Male', 'Female', 'Female'],
    'capital-gain': [2174, 111, 993]
}
df = pd.DataFrame(personal_data_dict)

# %%
df
# Out:
#    age  capital-gain  education    occupation     sex
# 0   39          2174  Bachelors  Adm-clerical    Male
# 1   50           111  Bachelors  Tech-support  Female
# 2   38           993    HS-grad         Sales  Female

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (3, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.values
# Out:
# array([[39, 2174, 'Bachelors', 'Adm-clerical', 'Male'],
#        [50, 111, 'Bachelors', 'Tech-support', 'Female'],
#        [38, 993, 'HS-grad', 'Sales', 'Female']], dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'capital-gain', 'education', 'occupation', 'sex'], dtype='object')

# %%
df.head(2)
# Out:
#    age  capital-gain  education    occupation     sex
# 0   39          2174  Bachelors  Adm-clerical    Male
# 1   50           111  Bachelors  Tech-support  Female

# %%
df.tail()
# Out:
#    age  capital-gain  education    occupation     sex
# 0   39          2174  Bachelors  Adm-clerical    Male
# 1   50           111  Bachelors  Tech-support  Female
# 2   38           993    HS-grad         Sales  Female

# %%
df['occupation']
# Out:
# 0    Adm-clerical
# 1    Tech-support
# 2           Sales
# Name: occupation, dtype: object

# %%
df['age'][1]
# Out:
# 50

# %%
df['capital-gain']
# Out:
# 0    2174
# 1     111
# 2     993
# Name: capital-gain, dtype: int64

# %%
df['name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-bb1c92367fe8> in <module>()
# ----> 1 df['name']
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'name'

# %%
df['age']
# Out:
# 0    39
# 1    50
# 2    38
# Name: age, dtype: int64

# %%
df.age.value_counts()
# Out:
# 39    1
# 50    1
# 38    1
# Name: age, dtype: int64

# %%
df.age.value_counts()

# %%
type(df.age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Pandas Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
# age             3 non-null int64
# capital-gain    3 non-null int64
# education       3 non-null object
# occupation      3 non-null object
# sex             3 non-null object
# dtypes: int64(2), object(3)
# memory usage: 200.0+ bytes

# %% [markdown]
# ## Knowing Basic Stats

# %%
df.describe()
# Out:
#              age  capital-gain
# count   3.000000      3.000000
# mean   42.333333   1092.666667
# std     6.658328   1035.104987
# min    38.000000    111.000000
# 25%    38.500000    552.000000
# 50%    39.000000    993.000000
# 75%    44.500000   1583.500000
# max    50.000000   2174.000000

# %%
df.cov()
# Out:
#                       age  capital-gain
# age             44.333333 -5.349333e+03
# capital-gain -5349.333333  1.071442e+06

# %%
df.corr()
# Out:
#                    age  capital-gain
# age           1.000000     -0.776158
# capital-gain -0.776158      1.000000

# %% [markdown]
# ## Dealing with Files

# %% [markdown]
# ### Reading Data from File

# %% [markdown]
# #### CSV File

# %% [markdown]
# UCI Machine Learning Repository: [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult)

# %%
adult = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data')

# %%
adult.head()
# Out:
#    39          State-gov   77516   Bachelors   13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors   13   Married-civ-spouse
# 1  38            Private  215646     HS-grad    9             Divorced
# 2  53            Private  234721        11th    7   Married-civ-spouse
# 3  28            Private  338409   Bachelors   13   Married-civ-spouse
# 4  37            Private  284582     Masters   14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family   White     Male   2174   0   40  \
# 0     Exec-managerial         Husband   White     Male      0   0   13
# 1   Handlers-cleaners   Not-in-family   White     Male      0   0   40
# 2   Handlers-cleaners         Husband   Black     Male      0   0   40
# 3      Prof-specialty            Wife   Black   Female      0   0   40
# 4     Exec-managerial            Wife   White   Female      0   0   40
#
#     United-States   <=50K
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3            Cuba   <=50K
# 4   United-States   <=50K

# %%
adult = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header=None)

# %%
adult.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# 3   United-States   <=50K
# 4            Cuba   <=50K

# %%
columns = ['age', 'Work Class', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'Money Per Year']
adult.columns = columns

# %%
adult.head(2)
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K

# %%
adult['age'][0:3]
# Out:
# 0    39
# 1    50
# 2    38
# Name: age, dtype: int64

# %%
columns = ['age', 'Work Class', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'Money Per Year']
adult = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', names=columns)

# %%
adult.head()

# %%
adult['age']

# %%
adult.age.value_counts(ascending=True)[0:5]
# Out:
# 86    1
# 87    1
# 88    3
# 85    3
# 83    6
# Name: age, dtype: int64

# %%
adult[adult.age == adult.age.value_counts().index[0]]['sex'].value_counts()
# Out:
#  Male      611
#  Female    287
# Name: sex, dtype: int64

# %% [markdown]
# #### JSON File

# %%
# !cat try_series.json
# Out:
# {
#     "name": "Kan Ouivirach",
#     "email": "kan@prontomarketing.com"
# }

# %%
series_data = pd.read_json('try_series.json', typ='series')

# %%
series_data
# Out:
# email    kan@prontomarketing.com
# name               Kan Ouivirach
# dtype: object

# %%
# !cat try_df.json
# Out:
# [
#     {
#         "name": "Kan Ouivirach",
#         "email": "kan@prontomarketing.com"
#     },
#     {
#         "name": "Some Data Scientist",
#         "email": "someone@datascience.th"
#     }
# ]

# %%
df = pd.read_json('try_df.json')

# %%
df
# Out:
#                      email                 name
# 0  kan@prontomarketing.com        Kan Ouivirach
# 1   someone@datascience.th  Some Data Scientist

# %% [markdown]
# ### Writing Data to File

# %%
adult.to_json('adult.json')

# %%
# !ls
# Out:
# adult.csv                       reviews_Digital_Music_5.csv
# adult.json                      reviews_Digital_Music_5.json.gz
# exercise2.csv                   try_df.json
# pandas-01.ipynb                 try_series.json
# pandas-02.ipynb

# %%
adult = pd.read_json('adult.json')

# %%
adult.head(3)
# Out:
#    Money Per Year         Work Class  age  capital-gain  capital-loss  \
# 0           <=50K          State-gov   39          2174             0
# 1           <=50K   Self-emp-not-inc   50             0             0
# 10           >50K            Private   37             0             0
#
#         education  education-num  fnlwgt  hours-per-week       marital-status  \
# 0       Bachelors             13   77516              40        Never-married
# 1       Bachelors             13   83311              13   Married-civ-spouse
# 10   Some-college             10  280464              80   Married-civ-spouse
#
#     native-country        occupation    race    relationship    sex
# 0    United-States      Adm-clerical   White   Not-in-family   Male
# 1    United-States   Exec-managerial   White         Husband   Male
# 10   United-States   Exec-managerial   Black         Husband   Male

# %%
adult.tto_csv('adult.csv')

# %%
# !ls

# %% [markdown]
# ## Dealing with Columns

# %% [markdown]
# ### Renaming Columns

# %%
adult = pd.read_csv('adult.csv', index_col=0)

# %%
adult.head()
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K

# %%
adult_new = adult.rename(columns={'Work Class': 'workclass'})

# %%
adult_new.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K

# %%
adult_new.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'Money Per Year'],
#       dtype='object')

# %%
adult_new.columns = adult_new.columns.str.lower().str.replace(' ', '-')

# %%
adult_new.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'money-per-year'],
#       dtype='object')

# %%
adult_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# money-per-year    32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Adding New Columns

# %%
adult['normalized-age'] = (adult.age - adult.age.mean()) / adult.age.std()

# %%
adult.head()
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year  \
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K
#
#    normalized-age
# 0        0.030670
# 1        0.837096
# 2       -0.042641
# 3        1.057031
# 4       -0.775756

# %%
adult['normalized-age'] > 1
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21        True
# 22       False
# 23       False
# 24        True
# 25        True
# 26       False
# 27        True
# 28       False
# 29       False
#          ...
# 32531    False
# 32532    False
# 32533     True
# 32534    False
# 32535    False
# 32536    False
# 32537    False
# 32538    False
# 32539     True
# 32540    False
# 32541    False
# 32542     True
# 32543    False
# 32544    False
# 32545    False
# 32546    False
# 32547    False
# 32548     True
# 32549    False
# 32550    False
# 32551    False
# 32552    False
# 32553    False
# 32554     True
# 32555    False
# 32556    False
# 32557    False
# 32558     True
# 32559    False
# 32560    False
# Name: normalized-age, dtype: bool

# %%
adult[adult['normalized-age'] > 1]
# Out:
#        age         Work Class  fnlwgt      education  education-num  \
# 3       53            Private  234721           11th              7
# 21      54            Private  302146        HS-grad              9
# 24      59            Private  109015        HS-grad              9
# 25      56          Local-gov  216851      Bachelors             13
# 27      54                  ?  180211   Some-college             10
# 41      53   Self-emp-not-inc   88506      Bachelors             13
# 45      57        Federal-gov  337895      Bachelors             13
# 46      53            Private  144361        HS-grad              9
# 67      53            Private  169846        HS-grad              9
# 74      79            Private  124744   Some-college             10
# 77      67                  ?  212759           10th              6
# 83      59            Private  159937        HS-grad              9
# 85      53            Private  346253        HS-grad              9
# 90      57            Private  249977      Assoc-voc             11
# 100     76            Private  124191        Masters             14
# 112     56   Self-emp-not-inc  335605        HS-grad              9
# 115     53            Private   95647            9th              5
# 116     56       Self-emp-inc  303090   Some-college             10
# 118     55            Private  247552   Some-college             10
# 140     61       Self-emp-inc   66614        HS-grad              9
# 144     70            Private  105376   Some-college             10
# 148     64            Private  181232           11th              7
# 157     71   Self-emp-not-inc  494223   Some-college             10
# 160     68                  ?   38317        1st-4th              2
# 169     66          Local-gov   54826      Assoc-voc             11
# 187     53                  ?  135105      Bachelors             13
# 189     58          State-gov  109567      Doctorate             16
# 208     58       Self-emp-inc  210563        HS-grad              9
# 213     60            Private   85815        HS-grad              9
# 214     54       Self-emp-inc  125417        7th-8th              4
# ...    ...                ...     ...            ...            ...
# 32415   57   Self-emp-not-inc   65080        HS-grad              9
# 32423   61            Private   98776           11th              7
# 32430   61   Self-emp-not-inc   50483        7th-8th              4
# 32438   66   Self-emp-not-inc  102686        Masters             14
# 32441   53            Private  304504   Some-college             10
# 32445   61            Private  190682        HS-grad              9
# 32446   53            Private  158993        HS-grad              9
# 32448   61            Private  137554        7th-8th              4
# 32459   85            Private   98611      Bachelors             13
# 32460   62            Private  128092        HS-grad              9
# 32463   58          Local-gov  223214        HS-grad              9
# 32465   66            Private  269665        HS-grad              9
# 32467   55            Private  199713            9th              5
# 32469   58       Self-emp-inc  181974      Doctorate             16
# 32479   64          State-gov  222966        7th-8th              4
# 32489   61            Private  355645        HS-grad              9
# 32490   60                  ?  134152            9th              5
# 32494   82                  ?  403910        HS-grad              9
# 32498   57            Private  153918        HS-grad              9
# 32501   71            Private  138145            9th              5
# 32515   66        Federal-gov   47358           10th              6
# 32518   57          Local-gov  110417        HS-grad              9
# 32522   58            Private  147707           11th              7
# 32525   81                  ?  120478      Assoc-voc             11
# 32533   54            Private  337992      Bachelors             13
# 32539   71                  ?  287372      Doctorate             16
# 32542   72                  ?  129912        HS-grad              9
# 32548   65   Self-emp-not-inc   99359    Prof-school             15
# 32554   53            Private  321865        Masters             14
# 32558   58            Private  151910        HS-grad              9
#
#             marital-status          occupation     relationship  \
# 3       Married-civ-spouse   Handlers-cleaners          Husband
# 21               Separated       Other-service        Unmarried
# 24                Divorced        Tech-support        Unmarried
# 25      Married-civ-spouse        Tech-support          Husband
# 27      Married-civ-spouse                   ?          Husband
# 41      Married-civ-spouse      Prof-specialty          Husband
# 45      Married-civ-spouse      Prof-specialty          Husband
# 46      Married-civ-spouse   Machine-op-inspct          Husband
# 67      Married-civ-spouse        Adm-clerical             Wife
# 74      Married-civ-spouse      Prof-specialty   Other-relative
# 77      Married-civ-spouse                   ?          Husband
# 83      Married-civ-spouse               Sales          Husband
# 85                Divorced               Sales        Own-child
# 90      Married-civ-spouse      Prof-specialty          Husband
# 100     Married-civ-spouse     Exec-managerial          Husband
# 112     Married-civ-spouse       Other-service          Husband
# 115     Married-civ-spouse   Handlers-cleaners          Husband
# 116     Married-civ-spouse               Sales          Husband
# 118     Married-civ-spouse               Sales          Husband
# 140     Married-civ-spouse        Craft-repair          Husband
# 144          Never-married        Tech-support   Other-relative
# 148     Married-civ-spouse        Craft-repair          Husband
# 157              Separated               Sales        Unmarried
# 160               Divorced                   ?    Not-in-family
# 169                Widowed      Prof-specialty    Not-in-family
# 187               Divorced                   ?    Not-in-family
# 189     Married-civ-spouse      Prof-specialty          Husband
# 208     Married-civ-spouse               Sales             Wife
# 213     Married-civ-spouse        Craft-repair          Husband
# 214     Married-civ-spouse   Machine-op-inspct          Husband
# ...                    ...                 ...              ...
# 32415   Married-civ-spouse        Craft-repair          Husband
# 32423              Widowed   Handlers-cleaners    Not-in-family
# 32430   Married-civ-spouse     Farming-fishing          Husband
# 32438   Married-civ-spouse     Exec-managerial          Husband
# 32441   Married-civ-spouse    Transport-moving          Husband
# 32445              Widowed        Craft-repair    Not-in-family
# 32446              Widowed   Machine-op-inspct        Unmarried
# 32448   Married-civ-spouse        Craft-repair          Husband
# 32459   Married-civ-spouse     Exec-managerial          Husband
# 32460              Widowed        Adm-clerical    Not-in-family
# 32463   Married-civ-spouse       Other-service          Husband
# 32465              Widowed     Exec-managerial    Not-in-family
# 32467   Married-civ-spouse        Craft-repair          Husband
# 32469        Never-married      Prof-specialty    Not-in-family
# 32479   Married-civ-spouse       Other-service             Wife
# 32489   Married-civ-spouse               Sales          Husband
# 32490             Divorced                   ?    Not-in-family
# 32494        Never-married                   ?    Not-in-family
# 32498   Married-civ-spouse    Transport-moving          Husband
# 32501   Married-civ-spouse       Other-service          Husband
# 32515   Married-civ-spouse        Craft-repair          Husband
# 32518   Married-civ-spouse        Craft-repair          Husband
# 32522   Married-civ-spouse               Sales          Husband
# 32525             Divorced                   ?        Unmarried
# 32533   Married-civ-spouse     Exec-managerial          Husband
# 32539   Married-civ-spouse                   ?          Husband
# 32542   Married-civ-spouse                   ?          Husband
# 32548        Never-married      Prof-specialty    Not-in-family
# 32554   Married-civ-spouse     Exec-managerial          Husband
# 32558              Widowed        Adm-clerical        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 3                    Black     Male             0             0
# 21                   Black   Female             0             0
# 24                   White   Female             0             0
# 25                   White     Male             0             0
# 27      Asian-Pac-Islander     Male             0             0
# 41                   White     Male             0             0
# 45                   Black     Male             0             0
# 46                   White     Male             0             0
# 67                   White   Female             0             0
# 74                   White     Male             0             0
# 77                   White     Male             0             0
# 83                   White     Male             0             0
# 85                   White   Female             0             0
# 90                   White     Male             0             0
# 100                  White     Male             0             0
# 112                  White     Male             0          1887
# 115                  White     Male             0             0
# 116                  White     Male             0             0
# 118                  White     Male             0             0
# 140                  White     Male             0             0
# 144                  White     Male             0             0
# 148                  White     Male             0          2179
# 157                  Black     Male             0          1816
# 160                  White   Female             0             0
# 169                  White   Female             0             0
# 187                  White   Female             0             0
# 189                  White     Male             0             0
# 208                  White   Female         15024             0
# 213     Asian-Pac-Islander     Male             0             0
# 214                  White     Male             0             0
# ...                    ...      ...           ...           ...
# 32415                White     Male             0             0
# 32423                White   Female             0             0
# 32430                White     Male             0             0
# 32438                White     Male             0             0
# 32441                White     Male             0          1887
# 32445                Black   Female             0          1669
# 32446                Black   Female             0             0
# 32448                White     Male             0             0
# 32459                White     Male             0             0
# 32460                White   Female             0             0
# 32463                White     Male             0             0
# 32465                White   Female             0             0
# 32467                White     Male             0             0
# 32469                White   Female             0             0
# 32479                Black   Female             0             0
# 32489                Black     Male             0             0
# 32490                Black     Male             0             0
# 32494                White     Male             0             0
# 32498                White     Male             0             0
# 32501                White     Male             0             0
# 32515                White     Male          3471             0
# 32518                White     Male         99999             0
# 32522                White     Male             0             0
# 32525                White   Female             0             0
# 32533   Asian-Pac-Islander     Male             0             0
# 32539                White     Male             0             0
# 32542                White     Male             0             0
# 32548                White     Male          1086             0
# 32554                White     Male             0             0
# 32558                White   Female             0             0
#
#        hours-per-week  native-country Money Per Year  normalized-age
# 3                  40   United-States          <=50K        1.057031
# 21                 20   United-States          <=50K        1.130342
# 24                 40   United-States          <=50K        1.496899
# 25                 40   United-States           >50K        1.276965
# 27                 60           South           >50K        1.130342
# 41                 40   United-States          <=50K        1.057031
# 45                 40   United-States           >50K        1.350276
# 46                 38   United-States          <=50K        1.057031
# 67                 40   United-States           >50K        1.057031
# 74                 20   United-States          <=50K        2.963128
# 77                  2   United-States          <=50K        2.083391
# 83                 48   United-States          <=50K        1.496899
# 85                 35   United-States          <=50K        1.057031
# 90                 40   United-States          <=50K        1.350276
# 100                40   United-States           >50K        2.743194
# 112                50          Canada           >50K        1.276965
# 115                50   United-States          <=50K        1.057031
# 116                50   United-States          <=50K        1.276965
# 118                56   United-States          <=50K        1.203653
# 140                40   United-States          <=50K        1.643522
# 144                40   United-States          <=50K        2.303325
# 148                40   United-States          <=50K        1.863457
# 157                 2   United-States          <=50K        2.376637
# 160                20   United-States          <=50K        2.156702
# 169                20   United-States          <=50K        2.010079
# 187                50   United-States          <=50K        1.057031
# 189                 1   United-States           >50K        1.423588
# 208                35   United-States           >50K        1.423588
# 213                40   United-States          <=50K        1.570211
# 214                40   United-States           >50K        1.130342
# ...               ...             ...            ...             ...
# 32415              50   United-States           >50K        1.350276
# 32423              30   United-States          <=50K        1.643522
# 32430              56   United-States          <=50K        1.643522
# 32438              20   United-States           >50K        2.010079
# 32441              45   United-States           >50K        1.057031
# 32445              50   United-States          <=50K        1.643522
# 32446              38   United-States          <=50K        1.057031
# 32448              40   United-States          <=50K        1.643522
# 32459               3          Poland          <=50K        3.402997
# 32460              32   United-States          <=50K        1.716834
# 32463              40   United-States          <=50K        1.423588
# 32465              25   United-States          <=50K        2.010079
# 32467              48   United-States          <=50K        1.203653
# 32469              99               ?          <=50K        1.423588
# 32479              40   United-States          <=50K        1.863457
# 32489              40   United-States          <=50K        1.643522
# 32490              35   United-States          <=50K        1.570211
# 32494               3   United-States          <=50K        3.183063
# 32498              40   United-States          <=50K        1.350276
# 32501              40   United-States          <=50K        2.376637
# 32515              40   United-States          <=50K        2.010079
# 32518              40   United-States           >50K        1.350276
# 32522              40   United-States          <=50K        1.423588
# 32525               1               ?          <=50K        3.109751
# 32533              50           Japan           >50K        1.130342
# 32539              10   United-States           >50K        2.376637
# 32542              25   United-States          <=50K        2.449948
# 32548              60   United-States          <=50K        1.936768
# 32554              40   United-States           >50K        1.057031
# 32558              40   United-States          <=50K        1.423588
#
# [5387 rows x 16 columns]

# %%
adult[adult['age'] > 80]
# Out:
#        age         Work Class  fnlwgt      education  education-num  \
# 222     90            Private   51744        HS-grad              9
# 918     81   Self-emp-not-inc  136063        HS-grad              9
# 1040    90            Private  137018        HS-grad              9
# 1168    88   Self-emp-not-inc  206291    Prof-school             15
# 1935    90            Private  221832      Bachelors             13
# 2303    90            Private   52386   Some-college             10
# 2891    90            Private  171956   Some-college             10
# 2906    81            Private  114670            9th              5
# 3211    82                  ?   29441        7th-8th              4
# 3537    81   Self-emp-not-inc  137018        HS-grad              9
# 3963    83                  ?  251951        HS-grad              9
# 4070    90            Private  313986           11th              7
# 4109    90                  ?  256514      Bachelors             13
# 4834    81            Private  364099   Some-college             10
# 5104    90            Private   52386   Some-college             10
# 5272    90            Private  141758            9th              5
# 5370    90          Local-gov  227796        Masters             14
# 5406    90            Private   51744        Masters             14
# 6214    84   Self-emp-not-inc  155057      Bachelors             13
# 6232    90   Self-emp-not-inc  155981      Bachelors             13
# 6624    90            Private  313986           11th              7
# 6748    81            Private  122651   Some-college             10
# 7481    83            Private  195507        HS-grad              9
# 7720    84            Private  241065        Masters             14
# 7872    81                  ?  162882        HS-grad              9
# 8381    85            Private  115364        HS-grad              9
# 8431    82            Private  152148        7th-8th              4
# 8806    90            Private   87372    Prof-school             15
# 8963    90                  ?   77053        HS-grad              9
# 8973    90            Private   46786      Bachelors             13
# ...    ...                ...     ...            ...            ...
# 21812   82                  ?  194590      Assoc-voc             11
# 21835   88   Self-emp-not-inc  187097    Prof-school             15
# 22220   90            Private   52386      Bachelors             13
# 22481   82       Self-emp-inc  120408   Some-college             10
# 22895   88            Private   68539   Some-college             10
# 22898   84                  ?  127184        5th-6th              3
# 23459   83       Self-emp-inc  240150           10th              6
# 24027   86            Private  149912        Masters             14
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 24238   90                  ?  166343        1st-4th              2
# 24280   82       Self-emp-inc  130329        7th-8th              4
# 24395   83       Self-emp-inc  153183      Bachelors             13
# 24560   81            Private   98116      Bachelors             13
# 25303   90                  ?  175444        7th-8th              4
# 26012   81                  ?  106765   Some-college             10
# 26731   84            Private  188328        HS-grad              9
# 27795   84            Private  388384        7th-8th              4
# 28463   90        Federal-gov  195433        HS-grad              9
# 28948   81            Private  129338        7th-8th              4
# 29594   81   Self-emp-not-inc  193237        1st-4th              2
# 29724   81                  ?   89391    Prof-school             15
# 31030   90            Private   47929        HS-grad              9
# 31432   87                  ?   90338        HS-grad              9
# 31696   90                  ?  313986        HS-grad              9
# 31855   82   Self-emp-not-inc   71438        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 32367   90          Local-gov  214594        7th-8th              4
# 32459   85            Private   98611      Bachelors             13
# 32494   82                  ?  403910        HS-grad              9
# 32525   81                  ?  120478      Assoc-voc             11
#
#             marital-status          occupation     relationship  \
# 222          Never-married       Other-service    Not-in-family
# 918     Married-civ-spouse     Exec-managerial          Husband
# 1040         Never-married       Other-service    Not-in-family
# 1168    Married-civ-spouse      Prof-specialty          Husband
# 1935    Married-civ-spouse     Exec-managerial          Husband
# 2303         Never-married       Other-service    Not-in-family
# 2891             Separated        Adm-clerical        Own-child
# 2906               Widowed     Priv-house-serv    Not-in-family
# 3211               Widowed                   ?    Not-in-family
# 3537               Widowed        Adm-clerical    Not-in-family
# 3963               Widowed                   ?    Not-in-family
# 4070         Never-married   Handlers-cleaners        Own-child
# 4109               Widowed                   ?   Other-relative
# 4834              Divorced        Adm-clerical    Not-in-family
# 5104         Never-married       Other-service    Not-in-family
# 5272         Never-married        Adm-clerical    Not-in-family
# 5370    Married-civ-spouse     Exec-managerial          Husband
# 5406         Never-married     Exec-managerial    Not-in-family
# 6214    Married-civ-spouse     Farming-fishing          Husband
# 6232    Married-civ-spouse      Prof-specialty          Husband
# 6624    Married-civ-spouse        Craft-repair          Husband
# 6748    Married-civ-spouse               Sales          Husband
# 7481               Widowed     Protective-serv    Not-in-family
# 7720         Never-married      Prof-specialty    Not-in-family
# 7872              Divorced                   ?    Not-in-family
# 8381               Widowed               Sales        Unmarried
# 8431    Married-civ-spouse   Handlers-cleaners          Husband
# 8806    Married-civ-spouse      Prof-specialty          Husband
# 8963               Widowed                   ?    Not-in-family
# 8973    Married-civ-spouse               Sales          Husband
# ...                    ...                 ...              ...
# 21812              Widowed                   ?    Not-in-family
# 21835   Married-civ-spouse     Exec-managerial          Husband
# 22220        Never-married      Prof-specialty    Not-in-family
# 22481              Widowed               Sales    Not-in-family
# 22895             Divorced        Adm-clerical        Unmarried
# 22898   Married-civ-spouse                   ?          Husband
# 23459   Married-civ-spouse     Farming-fishing          Husband
# 24027        Never-married        Adm-clerical    Not-in-family
# 24043        Never-married     Exec-managerial    Not-in-family
# 24238              Widowed                   ?    Not-in-family
# 24280   Married-civ-spouse     Farming-fishing          Husband
# 24395   Married-civ-spouse     Exec-managerial          Husband
# 24560              Widowed               Sales    Not-in-family
# 25303            Separated                   ?    Not-in-family
# 26012              Widowed                   ?        Unmarried
# 26731              Widowed      Prof-specialty    Not-in-family
# 27795   Married-civ-spouse      Prof-specialty          Husband
# 28463   Married-civ-spouse        Craft-repair          Husband
# 28948   Married-civ-spouse    Transport-moving          Husband
# 29594              Widowed               Sales   Other-relative
# 29724   Married-civ-spouse                   ?          Husband
# 31030   Married-civ-spouse   Machine-op-inspct          Husband
# 31432              Widowed                   ?    Not-in-family
# 31696   Married-civ-spouse                   ?          Husband
# 31855   Married-civ-spouse     Farming-fishing          Husband
# 32277              Widowed        Adm-clerical        Unmarried
# 32367   Married-civ-spouse     Protective-serv          Husband
# 32459   Married-civ-spouse     Exec-managerial          Husband
# 32494        Never-married                   ?    Not-in-family
# 32525             Divorced                   ?        Unmarried
#
#                       race      sex  capital-gain  capital-loss  \
# 222                  Black     Male             0          2206
# 918                  White     Male             0             0
# 1040                 White   Female             0             0
# 1168                 White     Male             0             0
# 1935                 White     Male             0             0
# 2303    Asian-Pac-Islander     Male             0             0
# 2891                 White   Female             0             0
# 2906                 Black   Female          2062             0
# 3211                 White     Male             0             0
# 3537                 White   Female             0             0
# 3963                 White   Female             0             0
# 4070                 White     Male             0             0
# 4109                 White   Female           991             0
# 4834                 White   Female             0             0
# 5104    Asian-Pac-Islander     Male             0             0
# 5272                 White   Female             0             0
# 5370                 White     Male         20051             0
# 5406                 Black     Male             0             0
# 6214                 White     Male             0             0
# 6232                 White     Male         10566             0
# 6624                 White     Male             0             0
# 6748                 White     Male             0             0
# 7481                 White     Male             0             0
# 7720                 White     Male             0             0
# 7872                 White   Female             0             0
# 8381                 White     Male             0             0
# 8431                 White     Male             0             0
# 8806                 White     Male         20051             0
# 8963                 White   Female             0          4356
# 8973                 White     Male          9386             0
# ...                    ...      ...           ...           ...
# 21812                White   Female             0             0
# 21835                White     Male             0             0
# 22220   Asian-Pac-Islander     Male             0             0
# 22481                White     Male             0             0
# 22895                White   Female             0             0
# 22898                White     Male             0             0
# 23459                White     Male         20051             0
# 24027                White   Female             0             0
# 24043                White     Male          2964             0
# 24238                Black   Female             0             0
# 24280                White     Male             0             0
# 24395                White     Male             0          2392
# 24560                White     Male             0             0
# 25303                White   Female             0             0
# 26012                White   Female             0             0
# 26731                White   Female             0             0
# 27795                Black     Male             0             0
# 28463                White     Male             0             0
# 28948                White     Male             0             0
# 29594                White     Male             0             0
# 29724                White     Male             0             0
# 31030                White     Male             0             0
# 31432                White     Male             0             0
# 31696                White     Male             0             0
# 31855                White     Male             0             0
# 32277                White   Female             0             0
# 32367                White     Male          2653             0
# 32459                White     Male             0             0
# 32494                White     Male             0             0
# 32525                White   Female             0             0
#
#        hours-per-week  native-country Money Per Year  normalized-age
# 222                40   United-States          <=50K        3.769554
# 918                30   United-States          <=50K        3.109751
# 1040               40   United-States          <=50K        3.769554
# 1168               40   United-States          <=50K        3.622932
# 1935               45   United-States          <=50K        3.769554
# 2303               35   United-States          <=50K        3.769554
# 2891               40     Puerto-Rico          <=50K        3.769554
# 2906                5   United-States          <=50K        3.109751
# 3211                5   United-States          <=50K        3.183063
# 3537               20   United-States          <=50K        3.109751
# 3963               20   United-States          <=50K        3.256374
# 4070               40   United-States          <=50K        3.769554
# 4109               10   United-States          <=50K        3.769554
# 4834               20   United-States          <=50K        3.109751
# 5104               35   United-States          <=50K        3.769554
# 5272               40   United-States          <=50K        3.769554
# 5370               60   United-States           >50K        3.769554
# 5406               50   United-States           >50K        3.769554
# 6214               20   United-States          <=50K        3.329686
# 6232               50   United-States          <=50K        3.769554
# 6624               40   United-States          <=50K        3.769554
# 6748               15   United-States          <=50K        3.109751
# 7481               55   United-States          <=50K        3.256374
# 7720               66   United-States          <=50K        3.329686
# 7872               35   United-States          <=50K        3.109751
# 8381               35   United-States          <=50K        3.402997
# 8431                2   United-States          <=50K        3.183063
# 8806               72   United-States           >50K        3.769554
# 8963               40   United-States          <=50K        3.769554
# 8973               15   United-States           >50K        3.769554
# ...               ...             ...            ...             ...
# 21812               8   United-States          <=50K        3.183063
# 21835              40   United-States          <=50K        3.622932
# 22220              40   United-States          <=50K        3.769554
# 22481              20   United-States          <=50K        3.183063
# 22895              40   United-States          <=50K        3.622932
# 22898              20   United-States          <=50K        3.329686
# 23459              50   United-States           >50K        3.256374
# 24027              40   United-States          <=50K        3.476309
# 24043              12   United-States          <=50K        3.769554
# 24238              40   United-States          <=50K        3.769554
# 24280              50   United-States          <=50K        3.183063
# 24395              55   United-States           >50K        3.256374
# 24560              50   United-States           >50K        3.109751
# 25303              15   United-States          <=50K        3.769554
# 26012               4   United-States          <=50K        3.109751
# 26731              16   United-States          <=50K        3.329686
# 27795              10   United-States          <=50K        3.329686
# 28463              30   United-States          <=50K        3.769554
# 28948              10   United-States          <=50K        3.109751
# 29594              45          Mexico          <=50K        3.109751
# 29724              24   United-States           >50K        3.109751
# 31030              40   United-States          <=50K        3.769554
# 31432               2   United-States          <=50K        3.549620
# 31696              40   United-States           >50K        3.769554
# 31855              20   United-States          <=50K        3.183063
# 32277              25   United-States          <=50K        3.769554
# 32367              40   United-States          <=50K        3.769554
# 32459               3          Poland          <=50K        3.402997
# 32494               3   United-States          <=50K        3.183063
# 32525               1               ?          <=50K        3.109751
#
# [99 rows x 16 columns]

# %%
adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32561 entries, 0 to 32560
# Data columns (total 16 columns):
# age               32561 non-null int64
# Work Class        32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# Money Per Year    32561 non-null object
# normalized-age    32561 non-null float64
# dtypes: float64(1), int64(6), object(9)
# memory usage: 4.2+ MB

# %% [markdown]
# ### Removing Existing Columns

# %%
adult.drop('normalized-age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-d27f55d930cf> in <module>()
# ----> 1 adult.drop('normalized-age')
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    1875                 new_axis = axis.drop(labels, level=level, errors=errors)
#    1876             else:
# -> 1877                 new_axis = axis.drop(labels, errors=errors)
#    1878             dropped = self.reindex(**{axis_name: new_axis})
#    1879             try:
#
# /Users/zkan/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in drop(self, labels, errors)
#    3049             if errors != 'ignore':
#    3050                 raise ValueError('labels %s not contained in axis' %
# -> 3051                                  labels[mask])
#    3052             indexer = indexer[~mask]
#    3053         return self.delete(indexer)
#
# ValueError: labels ['normalized-age'] not contained in axis

# %% [markdown]
# We need to specify the parameter called `axis` when we drop.

# %%
adult.drop('normalized-age', axis=1)
# Out:
#        age         Work Class  fnlwgt      education  education-num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# 13      32            Private  205019     Assoc-acdm             12
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# 16      25   Self-emp-not-inc  176756        HS-grad              9
# 17      32            Private  186824        HS-grad              9
# 18      38            Private   28887           11th              7
# 19      43   Self-emp-not-inc  292175        Masters             14
# 20      40            Private  193524      Doctorate             16
# 21      54            Private  302146        HS-grad              9
# 22      35        Federal-gov   76845            9th              5
# 23      43            Private  117037           11th              7
# 24      59            Private  109015        HS-grad              9
# 25      56          Local-gov  216851      Bachelors             13
# 26      19            Private  168294        HS-grad              9
# 27      54                  ?  180211   Some-college             10
# 28      39            Private  367260        HS-grad              9
# 29      49            Private  193366        HS-grad              9
# ...    ...                ...     ...            ...            ...
# 32531   30                  ?   33811      Bachelors             13
# 32532   34            Private  204461      Doctorate             16
# 32533   54            Private  337992      Bachelors             13
# 32534   37            Private  179137   Some-college             10
# 32535   22            Private  325033           12th              8
# 32536   34            Private  160216      Bachelors             13
# 32537   30            Private  345898        HS-grad              9
# 32538   38            Private  139180      Bachelors             13
# 32539   71                  ?  287372      Doctorate             16
# 32540   45          State-gov  252208        HS-grad              9
# 32541   41                  ?  202822        HS-grad              9
# 32542   72                  ?  129912        HS-grad              9
# 32543   45          Local-gov  119199     Assoc-acdm             12
# 32544   31            Private  199655        Masters             14
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32546   37            Private  198216     Assoc-acdm             12
# 32547   43            Private  260761        HS-grad              9
# 32548   65   Self-emp-not-inc   99359    Prof-school             15
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation     relationship  \
# 0               Never-married        Adm-clerical    Not-in-family
# 1          Married-civ-spouse     Exec-managerial          Husband
# 2                    Divorced   Handlers-cleaners    Not-in-family
# 3          Married-civ-spouse   Handlers-cleaners          Husband
# 4          Married-civ-spouse      Prof-specialty             Wife
# 5          Married-civ-spouse     Exec-managerial             Wife
# 6       Married-spouse-absent       Other-service    Not-in-family
# 7          Married-civ-spouse     Exec-managerial          Husband
# 8               Never-married      Prof-specialty    Not-in-family
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse     Exec-managerial          Husband
# 11         Married-civ-spouse      Prof-specialty          Husband
# 12              Never-married        Adm-clerical        Own-child
# 13              Never-married               Sales    Not-in-family
# 14         Married-civ-spouse        Craft-repair          Husband
# 15         Married-civ-spouse    Transport-moving          Husband
# 16              Never-married     Farming-fishing        Own-child
# 17              Never-married   Machine-op-inspct        Unmarried
# 18         Married-civ-spouse               Sales          Husband
# 19                   Divorced     Exec-managerial        Unmarried
# 20         Married-civ-spouse      Prof-specialty          Husband
# 21                  Separated       Other-service        Unmarried
# 22         Married-civ-spouse     Farming-fishing          Husband
# 23         Married-civ-spouse    Transport-moving          Husband
# 24                   Divorced        Tech-support        Unmarried
# 25         Married-civ-spouse        Tech-support          Husband
# 26              Never-married        Craft-repair        Own-child
# 27         Married-civ-spouse                   ?          Husband
# 28                   Divorced     Exec-managerial    Not-in-family
# 29         Married-civ-spouse        Craft-repair          Husband
# ...                       ...                 ...              ...
# 32531           Never-married                   ?    Not-in-family
# 32532      Married-civ-spouse      Prof-specialty          Husband
# 32533      Married-civ-spouse     Exec-managerial          Husband
# 32534                Divorced        Adm-clerical        Unmarried
# 32535           Never-married     Protective-serv        Own-child
# 32536           Never-married     Exec-managerial    Not-in-family
# 32537           Never-married        Craft-repair    Not-in-family
# 32538                Divorced      Prof-specialty        Unmarried
# 32539      Married-civ-spouse                   ?          Husband
# 32540               Separated        Adm-clerical        Own-child
# 32541               Separated                   ?    Not-in-family
# 32542      Married-civ-spouse                   ?          Husband
# 32543                Divorced      Prof-specialty        Unmarried
# 32544                Divorced       Other-service    Not-in-family
# 32545      Married-civ-spouse        Adm-clerical             Wife
# 32546                Divorced        Tech-support    Not-in-family
# 32547      Married-civ-spouse   Machine-op-inspct          Husband
# 32548           Never-married      Prof-specialty    Not-in-family
# 32549                Divorced        Adm-clerical   Other-relative
# 32550      Married-civ-spouse        Craft-repair          Husband
# 32551      Married-civ-spouse   Handlers-cleaners          Husband
# 32552      Married-civ-spouse               Sales          Husband
# 32553           Never-married        Tech-support    Not-in-family
# 32554      Married-civ-spouse     Exec-managerial          Husband
# 32555           Never-married     Protective-serv    Not-in-family
# 32556      Married-civ-spouse        Tech-support             Wife
# 32557      Married-civ-spouse   Machine-op-inspct          Husband
# 32558                 Widowed        Adm-clerical        Unmarried
# 32559           Never-married        Adm-clerical        Own-child
# 32560      Married-civ-spouse     Exec-managerial             Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# 5                    White   Female             0             0
# 6                    Black   Female             0             0
# 7                    White     Male             0             0
# 8                    White   Female         14084             0
# 9                    White     Male          5178             0
# 10                   Black     Male             0             0
# 11      Asian-Pac-Islander     Male             0             0
# 12                   White   Female             0             0
# 13                   Black     Male             0             0
# 14      Asian-Pac-Islander     Male             0             0
# 15      Amer-Indian-Eskimo     Male             0             0
# 16                   White     Male             0             0
# 17                   White     Male             0             0
# 18                   White     Male             0             0
# 19                   White   Female             0             0
# 20                   White     Male             0             0
# 21                   Black   Female             0             0
# 22                   Black     Male             0             0
# 23                   White     Male             0          2042
# 24                   White   Female             0             0
# 25                   White     Male             0             0
# 26                   White     Male             0             0
# 27      Asian-Pac-Islander     Male             0             0
# 28                   White     Male             0             0
# 29                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32531   Asian-Pac-Islander   Female             0             0
# 32532                White     Male             0             0
# 32533   Asian-Pac-Islander     Male             0             0
# 32534                White   Female             0             0
# 32535                Black     Male             0             0
# 32536                White   Female             0             0
# 32537                Black     Male             0             0
# 32538                Black   Female         15020             0
# 32539                White     Male             0             0
# 32540                White   Female             0             0
# 32541                Black   Female             0             0
# 32542                White     Male             0             0
# 32543                White   Female             0             0
# 32544                Other   Female             0             0
# 32545                White   Female             0             0
# 32546                White   Female             0             0
# 32547                White     Male             0             0
# 32548                White     Male          1086             0
# 32549                White   Female             0             0
# 32550                White     Male             0             0
# 32551   Amer-Indian-Eskimo     Male             0             0
# 32552                White     Male             0             0
# 32553   Asian-Pac-Islander     Male             0             0
# 32554                White     Male             0             0
# 32555                White     Male             0             0
# 32556                White   Female             0             0
# 32557                White     Male             0             0
# 32558                White   Female             0             0
# 32559                White     Male             0             0
# 32560                White   Female         15024             0
#
#        hours-per-week  native-country Money Per Year
# 0                  40   United-States          <=50K
# 1                  13   United-States          <=50K
# 2                  40   United-States          <=50K
# 3                  40   United-States          <=50K
# 4                  40            Cuba          <=50K
# 5                  40   United-States          <=50K
# 6                  16         Jamaica          <=50K
# 7                  45   United-States           >50K
# 8                  50   United-States           >50K
# 9                  40   United-States           >50K
# 10                 80   United-States           >50K
# 11                 40           India           >50K
# 12                 30   United-States          <=50K
# 13                 50   United-States          <=50K
# 14                 40               ?           >50K
# 15                 45          Mexico          <=50K
# 16                 35   United-States          <=50K
# 17                 40   United-States          <=50K
# 18                 50   United-States          <=50K
# 19                 45   United-States           >50K
# 20                 60   United-States           >50K
# 21                 20   United-States          <=50K
# 22                 40   United-States          <=50K
# 23                 40   United-States          <=50K
# 24                 40   United-States          <=50K
# 25                 40   United-States           >50K
# 26                 40   United-States          <=50K
# 27                 60           South           >50K
# 28                 80   United-States          <=50K
# 29                 40   United-States          <=50K
# ...               ...             ...            ...
# 32531              99   United-States          <=50K
# 32532              60   United-States           >50K
# 32533              50           Japan           >50K
# 32534              39   United-States          <=50K
# 32535              35   United-States          <=50K
# 32536              55   United-States           >50K
# 32537              46   United-States          <=50K
# 32538              45   United-States           >50K
# 32539              10   United-States           >50K
# 32540              40   United-States          <=50K
# 32541              32   United-States          <=50K
# 32542              25   United-States          <=50K
# 32543              48   United-States          <=50K
# 32544              30   United-States          <=50K
# 32545              20   United-States           >50K
# 32546              40   United-States          <=50K
# 32547              40          Mexico          <=50K
# 32548              60   United-States          <=50K
# 32549              40   United-States          <=50K
# 32550              50   United-States          <=50K
# 32551              40   United-States          <=50K
# 32552              45   United-States          <=50K
# 32553              11          Taiwan          <=50K
# 32554              40   United-States           >50K
# 32555              40   United-States          <=50K
# 32556              38   United-States          <=50K
# 32557              40   United-States           >50K
# 32558              40   United-States          <=50K
# 32559              20   United-States          <=50K
# 32560              40   United-States           >50K
#
# [32561 rows x 15 columns]

# %%
adult.head()
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year  \
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K
#
#    normalized-age
# 0        0.030670
# 1        0.837096
# 2       -0.042641
# 3        1.057031
# 4       -0.775756

# %%
adult = adult.drop('normalized-age', axis=1)

# %%
adult.head()
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K

# %%
adult.head()
# Out:
#    age         Work Class  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country Money Per Year
# 0          2174             0              40   United-States          <=50K
# 1             0             0              13   United-States          <=50K
# 2             0             0              40   United-States          <=50K
# 3             0             0              40   United-States          <=50K
# 4             0             0              40            Cuba          <=50K

# %%
adult.drop([0, 1, axis=0)
# Out:
#        age         Work Class  fnlwgt      education  education-num  \
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# 13      32            Private  205019     Assoc-acdm             12
# 14      40            Private  121772      Assoc-voc             11
# 15      34            Private  245487        7th-8th              4
# 16      25   Self-emp-not-inc  176756        HS-grad              9
# 17      32            Private  186824        HS-grad              9
# 18      38            Private   28887           11th              7
# 19      43   Self-emp-not-inc  292175        Masters             14
# 20      40            Private  193524      Doctorate             16
# 21      54            Private  302146        HS-grad              9
# 22      35        Federal-gov   76845            9th              5
# 23      43            Private  117037           11th              7
# 24      59            Private  109015        HS-grad              9
# 25      56          Local-gov  216851      Bachelors             13
# 26      19            Private  168294        HS-grad              9
# 27      54                  ?  180211   Some-college             10
# 28      39            Private  367260        HS-grad              9
# 29      49            Private  193366        HS-grad              9
# 30      23          Local-gov  190709     Assoc-acdm             12
# ...    ...                ...     ...            ...            ...
# 32531   30                  ?   33811      Bachelors             13
# 32532   34            Private  204461      Doctorate             16
# 32533   54            Private  337992      Bachelors             13
# 32534   37            Private  179137   Some-college             10
# 32535   22            Private  325033           12th              8
# 32536   34            Private  160216      Bachelors             13
# 32537   30            Private  345898        HS-grad              9
# 32538   38            Private  139180      Bachelors             13
# 32539   71                  ?  287372      Doctorate             16
# 32540   45          State-gov  252208        HS-grad              9
# 32541   41                  ?  202822        HS-grad              9
# 32542   72                  ?  129912        HS-grad              9
# 32543   45          Local-gov  119199     Assoc-acdm             12
# 32544   31            Private  199655        Masters             14
# 32545   39          Local-gov  111499     Assoc-acdm             12
# 32546   37            Private  198216     Assoc-acdm             12
# 32547   43            Private  260761        HS-grad              9
# 32548   65   Self-emp-not-inc   99359    Prof-school             15
# 32549   43          State-gov  255835   Some-college             10
# 32550   43   Self-emp-not-inc   27242   Some-college             10
# 32551   32            Private   34066           10th              6
# 32552   43            Private   84661      Assoc-voc             11
# 32553   32            Private  116138        Masters             14
# 32554   53            Private  321865        Masters             14
# 32555   22            Private  310152   Some-college             10
# 32556   27            Private  257302     Assoc-acdm             12
# 32557   40            Private  154374        HS-grad              9
# 32558   58            Private  151910        HS-grad              9
# 32559   22            Private  201490        HS-grad              9
# 32560   52       Self-emp-inc  287927        HS-grad              9
#
#                marital-status          occupation     relationship  \
# 1          Married-civ-spouse     Exec-managerial          Husband
# 2                    Divorced   Handlers-cleaners    Not-in-family
# 3          Married-civ-spouse   Handlers-cleaners          Husband
# 4          Married-civ-spouse      Prof-specialty             Wife
# 5          Married-civ-spouse     Exec-managerial             Wife
# 6       Married-spouse-absent       Other-service    Not-in-family
# 7          Married-civ-spouse     Exec-managerial          Husband
# 8               Never-married      Prof-specialty    Not-in-family
# 9          Married-civ-spouse     Exec-managerial          Husband
# 10         Married-civ-spouse     Exec-managerial          Husband
# 11         Married-civ-spouse      Prof-specialty          Husband
# 12              Never-married        Adm-clerical        Own-child
# 13              Never-married               Sales    Not-in-family
# 14         Married-civ-spouse        Craft-repair          Husband
# 15         Married-civ-spouse    Transport-moving          Husband
# 16              Never-married     Farming-fishing        Own-child
# 17              Never-married   Machine-op-inspct        Unmarried
# 18         Married-civ-spouse               Sales          Husband
# 19                   Divorced     Exec-managerial        Unmarried
# 20         Married-civ-spouse      Prof-specialty          Husband
# 21                  Separated       Other-service        Unmarried
# 22         Married-civ-spouse     Farming-fishing          Husband
# 23         Married-civ-spouse    Transport-moving          Husband
# 24                   Divorced        Tech-support        Unmarried
# 25         Married-civ-spouse        Tech-support          Husband
# 26              Never-married        Craft-repair        Own-child
# 27         Married-civ-spouse                   ?          Husband
# 28                   Divorced     Exec-managerial    Not-in-family
# 29         Married-civ-spouse        Craft-repair          Husband
# 30              Never-married     Protective-serv    Not-in-family
# ...                       ...                 ...              ...
# 32531           Never-married                   ?    Not-in-family
# 32532      Married-civ-spouse      Prof-specialty          Husband
# 32533      Married-civ-spouse     Exec-managerial          Husband
# 32534                Divorced        Adm-clerical        Unmarried
# 32535           Never-married     Protective-serv        Own-child
# 32536           Never-married     Exec-managerial    Not-in-family
# 32537           Never-married        Craft-repair    Not-in-family
# 32538                Divorced      Prof-specialty        Unmarried
# 32539      Married-civ-spouse                   ?          Husband
# 32540               Separated        Adm-clerical        Own-child
# 32541               Separated                   ?    Not-in-family
# 32542      Married-civ-spouse                   ?          Husband
# 32543                Divorced      Prof-specialty        Unmarried
# 32544                Divorced       Other-service    Not-in-family
# 32545      Married-civ-spouse        Adm-clerical             Wife
# 32546                Divorced        Tech-support    Not-in-family
# 32547      Married-civ-spouse   Machine-op-inspct          Husband
# 32548           Never-married      Prof-specialty    Not-in-family
# 32549                Divorced        Adm-clerical   Other-relative
# 32550      Married-civ-spouse        Craft-repair          Husband
# 32551      Married-civ-spouse   Handlers-cleaners          Husband
# 32552      Married-civ-spouse               Sales          Husband
# 32553           Never-married        Tech-support    Not-in-family
# 32554      Married-civ-spouse     Exec-managerial          Husband
# 32555           Never-married     Protective-serv    Not-in-family
# 32556      Married-civ-spouse        Tech-support             Wife
# 32557      Married-civ-spouse   Machine-op-inspct          Husband
# 32558                 Widowed        Adm-clerical        Unmarried
# 32559           Never-married        Adm-clerical        Own-child
# 32560      Married-civ-spouse     Exec-managerial             Wife
#
#                       race      sex  capital-gain  capital-loss  \
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# 5                    White   Female             0             0
# 6                    Black   Female             0             0
# 7                    White     Male             0             0
# 8                    White   Female         14084             0
# 9                    White     Male          5178             0
# 10                   Black     Male             0             0
# 11      Asian-Pac-Islander     Male             0             0
# 12                   White   Female             0             0
# 13                   Black     Male             0             0
# 14      Asian-Pac-Islander     Male             0             0
# 15      Amer-Indian-Eskimo     Male             0             0
# 16                   White     Male             0             0
# 17                   White     Male             0             0
# 18                   White     Male             0             0
# 19                   White   Female             0             0
# 20                   White     Male             0             0
# 21                   Black   Female             0             0
# 22                   Black     Male             0             0
# 23                   White     Male             0          2042
# 24                   White   Female             0             0
# 25                   White     Male             0             0
# 26                   White     Male             0             0
# 27      Asian-Pac-Islander     Male             0             0
# 28                   White     Male             0             0
# 29                   White     Male             0             0
# 30                   White     Male             0             0
# ...                    ...      ...           ...           ...
# 32531   Asian-Pac-Islander   Female             0             0
# 32532                White     Male             0             0
# 32533   Asian-Pac-Islander     Male             0             0
# 32534                White   Female             0             0
# 32535                Black     Male             0             0
# 32536                White   Female             0             0
# 32537                Black     Male             0             0
# 32538                Black   Female         15020             0
# 32539                White     Male             0             0
# 32540                White   Female             0             0
# 32541                Black   Female             0             0
# 32542                White     Male             0             0
# 32543                White   Female             0             0
# 32544                Other   Female             0             0
# 32545                White   Female             0             0
# 32546                White   Female             0             0
# 32547                White     Male             0             0
# 32548                White     Male          1086             0
# 32549                White   Female             0             0
# 32550                White     Male             0             0
# 32551   Amer-Indian-Eskimo     Male             0             0
# 32552                White     Male             0             0
# 32553   Asian-Pac-Islander     Male             0             0
# 32554                White     Male             0             0
# 32555                White     Male             0             0
# 32556                White   Female             0             0
# 32557                White     Male             0             0
# 32558                White   Female             0             0
# 32559                White     Male             0             0
# 32560                White   Female         15024             0
#
#        hours-per-week  native-country Money Per Year
# 1                  13   United-States          <=50K
# 2                  40   United-States          <=50K
# 3                  40   United-States          <=50K
# 4                  40            Cuba          <=50K
# 5                  40   United-States          <=50K
# 6                  16         Jamaica          <=50K
# 7                  45   United-States           >50K
# 8                  50   United-States           >50K
# 9                  40   United-States           >50K
# 10                 80   United-States           >50K
# 11                 40           India           >50K
# 12                 30   United-States          <=50K
# 13                 50   United-States          <=50K
# 14                 40               ?           >50K
# 15                 45          Mexico          <=50K
# 16                 35   United-States          <=50K
# 17                 40   United-States          <=50K
# 18                 50   United-States          <=50K
# 19                 45   United-States           >50K
# 20                 60   United-States           >50K
# 21                 20   United-States          <=50K
# 22                 40   United-States          <=50K
# 23                 40   United-States          <=50K
# 24                 40   United-States          <=50K
# 25                 40   United-States           >50K
# 26                 40   United-States          <=50K
# 27                 60           South           >50K
# 28                 80   United-States          <=50K
# 29                 40   United-States          <=50K
# 30                 52   United-States          <=50K
# ...               ...             ...            ...
# 32531              99   United-States          <=50K
# 32532              60   United-States           >50K
# 32533              50           Japan           >50K
# 32534              39   United-States          <=50K
# 32535              35   United-States          <=50K
# 32536              55   United-States           >50K
# 32537              46   United-States          <=50K
# 32538              45   United-States           >50K
# 32539              10   United-States           >50K
# 32540              40   United-States          <=50K
# 32541              32   United-States          <=50K
# 32542              25   United-States          <=50K
# 32543              48   United-States          <=50K
# 32544              30   United-States          <=50K
# 32545              20   United-States           >50K
# 32546              40   United-States          <=50K
# 32547              40          Mexico          <=50K
# 32548              60   United-States          <=50K
# 32549              40   United-States          <=50K
# 32550              50   United-States          <=50K
# 32551              40   United-States          <=50K
# 32552              45   United-States          <=50K
# 32553              11          Taiwan          <=50K
# 32554              40   United-States           >50K
# 32555              40   United-States          <=50K
# 32556              38   United-States          <=50K
# 32557              40   United-States           >50K
# 32558              40   United-States          <=50K
# 32559              20   United-States          <=50K
# 32560              40   United-States           >50K
#
# [32560 rows x 15 columns]
